# %%
# %matplotlib inline

import numpy as np
import random
from matplotlib import pyplot as plt
from scipy.stats import truncnorm

# %%
# examples using truncnorm to sample from a truncated normal distribution


a, b = -0.1, 2
x = np.linspace(truncnorm.ppf(0.01, a, b),truncnorm.ppf(0.99, a, b), 100)
plt.plot(x, truncnorm.pdf(x, a, b),'r-', lw=5, alpha=0.6, label='truncnorm pdf')

# %%
r = truncnorm.rvs(a, b, size=1000)
plt.hist(r, bins = 20)
# Out:
# (array([85., 61., 84., 77., 68., 65., 62., 60., 77., 54., 63., 59., 40.,
#         28., 18., 19., 27., 19., 17., 17.]),
#  array([-0.09841794,  0.00629955,  0.11101704,  0.21573452,  0.32045201,
#          0.4251695 ,  0.52988699,  0.63460447,  0.73932196,  0.84403945,
#          0.94875694,  1.05347442,  1.15819191,  1.2629094 ,  1.36762689,
#          1.47234437,  1.57706186,  1.68177935,  1.78649684,  1.89121432,
#          1.99593181]),
#  <a list of 20 Patch objects>)
